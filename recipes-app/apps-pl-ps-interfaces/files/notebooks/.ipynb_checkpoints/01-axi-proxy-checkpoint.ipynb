# %% [markdown]
# # AXI Proxy
#
# Similar to AXI Traffic Generator, AXI Proxy is also an IP which can generate read and write bursts. In contrast to the Traffic Generator, there is always a single burst transmitted, and user has the possibility to set (for write transactions) or get (for read transactions) the first 4 32-bit values of the transaction.
#
# The AXI side-channels (`AxPROT`, `AxCACHE`, and `AxUSER`) can be set from software.
#
# AXI Proxy can be used to prototype the AXI interfaces before developing proper FPGA IPs.
#
# ![AXI Proxy in Vivado IP Integrator](./vivado_axi_proxy.png)

# %%
import logging
import re
import subprocess
from dataclasses import dataclass

import matplotlib.pyplot as plt
import numpy as np
from fpga_mngr_interface.FpgaManagerInterface import FpgaManagerInterface
from zynqmp_pl_ps import Udmabuf, UioDev

# %% [markdown]
# ## Programming the FPGA
#
# We check if the FPGA is programmed, and if that is not the case, we program it with the appropriate bitstream and device tree overlay.

# %%
# logging.basicConfig(level=logging.DEBUG)

fmi = FpgaManagerInterface()
is_programmed = fmi.is_programmed()

try:
    UioDev.get_uio_dev_file("AxiProxy", "hp")
    ap_found = True
except RuntimeError:
    ap_found = False

print(f"is programmed: {is_programmed}, AXI Proxy found: {ap_found}")

if not is_programmed or not ap_found:
    print("Re-programming the FPGA")
    fmi.remove()
    fmi.program_bitstream(
        "/lib/firmware/xilinx/axi_proxy/axi_proxy.bit.bin",
        "/lib/firmware/xilinx/axi_proxy/axi_proxy.dtbo",
    )
# Out:
# is programmed: True, AXI Proxy found: True

# %% [markdown]
# ## Infrastructure around `app-proxy`

# %%
@dataclass(frozen=True)
class Config:
    use_osync: bool
    axi_cache: int
    axi_prot: int
    axi_user: int


@dataclass(frozen=True)
class Stats:
    dur_wr: int
    dur_rd: int

# %%
RE_STATS = re.compile(r"stats: dur_wr = (?P<dur_wr>\d+), dur_rd = (?P<dur_rd>\d+)")

def run_ap(interface: str, config: Config) -> Stats:
    args = ["app-axi-proxy",
            "--interface", interface,
            "--data", *[str(xi) for xi in np.random.randint(0, np.iinfo(np.uint32).max, 4)],
            "--axi-prot", str(config.axi_prot),
            "--axi-cache", str(config.axi_cache),
            "--axi-user", str(config.axi_user)]

    if config.use_osync:
        args.append("--use-osync")

    resp = subprocess.check_output(args)

    for line in resp.decode("ascii").split("\n"):
        if m := RE_STATS.match(line):
            m_dict = {k: int(v) for k,v in m.groupdict().items()}
            return Stats(**m_dict)
        
    raise RuntimeError("Unable to find the 'stats:' line")

# %% [markdown]
# ## Measurement configuration

# %%
udmabuf = Udmabuf.Udmabuf("axi:udmabuf@0x0")
BUFFER_SIZE = udmabuf.buf_size
print(f"Buffer size: {BUFFER_SIZE}")
del udmabuf
# Out:
# Buffer size: 33554432

# %%
NR_MEAS_PER_PORT = 100

CONFIGS = {
    "hp": Config(use_osync=True, axi_cache=0, axi_prot=0, axi_user=0),
    "hpc": Config(use_osync=False, axi_cache=15, axi_prot=2, axi_user=1),
    "acp": Config(use_osync=False, axi_cache=15, axi_prot=2, axi_user=1),
}

# %% [markdown]
# ## Measurement

# %%
d=24), Stats(dur_wr=27, dur_rd=13), Stats(dur_wr=27, dur_rd=13), Stats(dur_wr=26, dur_rd=25), Stats(dur_wr=27, dur_rd=25), Stats(dur_wr=26, dur_rd=14), Stats(dur_wr=34, dur_rd=13), Stats(dur_wr=25, dur_rd=23), Stats(dur_wr=34, dur_rd=13), Stats(dur_wr=34, dur_rd=13), Stats(dur_wr=26, dur_rd=25), Stats(dur_wr=26, dur_rd=24),

# %% [markdown]
# ## Plotting

# %%
@dataclass
class MeasData:
    hp: np.array
    hpc: np.array
    acp: np.array


def process_meas(data: dict, tx_type: str):
    hp = np.array(data["hp"][tx_type])
    hpc = np.array(data["hpc"][tx_type])
    acp = np.array(data["acp"][tx_type])

    return MeasData(hp=hp, hpc=hpc, acp=acp)

def plot_graph_hist(
    ax1, ax2,
    meas_hp: np.array,
    meas_hpc: np.array,
    meas_acp: np.array,
    title: str,
):
    ax1.plot(meas_hp, label="HP")
    ax1.plot(meas_hpc, label="HPC")
    ax1.plot(meas_acp, label="ACP")
    ax1.grid(True)
    ax1.legend(loc="upper right")
    ax1.set_ylabel("delay [clk cycles]")
    ax1.set_xlabel("iteration")

    delay_max = np.max([np.max(meas_hp), np.max(meas_hpc), np.max(meas_acp)])
    delay_min = np.min([np.min(meas_hp), np.min(meas_hpc), np.min(meas_acp)])

    HIST_CONF = {
        "orientation": "horizontal",
        "alpha": 0.7,
    }
    ax2.hist(meas_hp, label="HP", bins=30, range=(delay_min, delay_max), **HIST_CONF)
    ax2.hist(meas_hpc, label="HPC", bins=30, range=(delay_min, delay_max), **HIST_CONF)
    ax2.hist(meas_acp, label="ACP", bins=30, range=(delay_min, delay_max), **HIST_CONF)
    ax2.grid(True)
    ax2.legend(loc="upper right")
    ax2.set_xlabel("counts")

    ax1.set_title(title)
    ax2.set_title(title + " (hist)")

# %%
data_read = process_meas(meas, "rd")
data_write = process_meas(meas, "wr")

# %%
fig = plt.figure(figsize=(12, 10))
[ax11, ax12], [ax21, ax22] = fig.subplots(
    2, 2, gridspec_kw={"width_ratios": [3, 1]}, sharey="row"
)


plot_graph_hist(
    ax11,
    ax12,
    data_write.hp,
    data_write.hpc,
    data_write.acp,
    "Write latency",
)
plot_graph_hist(
    ax21,
    ax22,
    data_read.hp,
    data_read.hpc,
    data_read.acp,
    "Read latency",
)

fig.suptitle("AXI Proxy, clk freq = 250 MHz")
# Out:
# Text(0.5, 0.98, 'AXI Proxy, clk freq = 250 MHz')

# %% [markdown]
# ## Conclusion
#
# * we have performed 100 runs, and in each run we have first written and then read a small chunk of memory (64 byte, a single cache line)
# * we can observe that the write latency is lowest for the ACP port, the HP port is in between and the highest on the HPC port
# * the read latency is again the lowest on the ACP port, the HPC is in between and the highest read latency is on the HP port
# * the write to HP port is faster than to HPC port; this is likely caused by the cache-coherent transactions happening between APU and CCI
# * the variability of the ACP latency is likely due to a different state of the cache line; please keep in mind that we start the external program (`app-axi-proxy`) for each measurement sample; this will be addressed in the next notebook
