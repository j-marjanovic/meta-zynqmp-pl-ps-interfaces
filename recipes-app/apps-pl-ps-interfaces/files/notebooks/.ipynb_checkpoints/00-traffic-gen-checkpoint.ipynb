# %% [markdown]
# # AXI Traffic Generator
#
# Jan Marjanovic, december 2021
#
# AXI Traffic Generator is used to generate a sequence of AXI burst; the data is a 128-bit-wide counter, which can be used to verify the content of the memory after the readback. The number of the burst is configurable from software. The Generator also measures the number of clock cycles it took to finish with the bursts, which can be used to calculate the latency.
#
# A chunk of physical memory was already allocated with [u-dma-buf](https://github.com/ikwzm/udmabuf) in the the device tree, and we will transfer the data to and from this memory.
#
# `app-axi-traffic-gen` is a program which can be used to control the AXI Traffic Generator; we will run the program with different settings (different PL-PS ports, differente transfer lengths, ...) and observe the throughput.
#
# ![AXI Traffic Generator in Vivado](./vivado_axi_tg.png)

# %%
import logging
import re
import subprocess
from dataclasses import dataclass

import matplotlib.pyplot as plt
import numpy as np
from fpga_mngr_interface.FpgaManagerInterface import FpgaManagerInterface
from zynqmp_pl_ps import Udmabuf, UioDev

# %% [markdown]
# ## Programming the FPGA
#
# We check if the FPGA is programmed, and if that is not the case, we program it with the appropriate bitstream and device tree overlay.

# %%
# logging.basicConfig(level=logging.DEBUG)

fmi = FpgaManagerInterface()
is_programmed = fmi.is_programmed()

try:
    UioDev.get_uio_dev_file("AxiTrafficGen", "hp")
    atg_found = True
except RuntimeError:
    atg_found = False

print(f"is programmed: {is_programmed}, AXI TG found: {atg_found}")

if not is_programmed or not atg_found:
    print("Re-programming the FPGA")
    fmi.remove()
    fmi.program_bitstream(
        "/lib/firmware/xilinx/axi_traffic_gen/axi_traffic_gen.bit.bin",
        "/lib/firmware/xilinx/axi_traffic_gen/axi_traffic_gen.dtbo",
    )
# Out:
# is programmed: True, AXI TG found: True

# %% [markdown]
# ## Infrastructure around `app-axi-traffic-gen`
#
# We prepare a function `run_atg` which will run the program (using `subprocess` library) and parse the output.

# %%
@dataclass(frozen=True)
class Config:
    use_osync: bool
    axi_cache: int
    axi_prot: int
    axi_user: int


@dataclass(frozen=True)
class Stats:
    rd_cyc: int
    wr_cyc: int
    count_beats: int

# %%
RE_STATS = re.compile(
    r"stats: rd cyc = (?P<rd_cyc>\d+), wr cyc = (?P<wr_cyc>\d+), rd_ok = (?P<count_beats>\d+)"
)


def run_atg(interface: str, size_bursts: int, config: Config) -> Stats:
    args = [
        "app-axi-traffic-gen",
        "--interface",
        interface,
        "--count",
        str(size_bursts),
        "--axi-prot",
        str(config.axi_prot),
        "--axi-cache",
        str(config.axi_cache),
        "--axi-user",
        str(config.axi_user),
    ]

    if config.use_osync:
        args.append("--use-osync")

    resp = subprocess.check_output(args)

    for line in resp.decode("ascii").split("\n"):
        if m := RE_STATS.match(line):
            m_dict = {k: int(v) for k, v in m.groupdict().items()}
            return Stats(**m_dict)

    raise RuntimeError("Unable to find the 'stats:' line")

# %% [markdown]
# ## Measurement configuration

# %%
udmabuf = Udmabuf.Udmabuf("axi:udmabuf@0x0")
BUFFER_SIZE = udmabuf.buf_size
print(f"Buffer size: {BUFFER_SIZE}")
del udmabuf
# Out:
# Buffer size: 33554432

# %%
NR_MEAS_PER_SIZE = 5

BYTES_PER_BEAT = 128 // 8
BEATS_PER_BURST = 4

sizes_burst = [
    2 ** i
    for i in range(int(np.log2(BUFFER_SIZE / BEATS_PER_BURST / BYTES_PER_BEAT)) + 1)
]

CONFIGS = {
    "hp": Config(use_osync=True, axi_cache=0, axi_prot=0, axi_user=0),
    "hpc": Config(use_osync=False, axi_cache=15, axi_prot=2, axi_user=1),
    "acp": Config(use_osync=False, axi_cache=15, axi_prot=2, axi_user=1),
}

# %% [markdown]
# ## Measurement

# %%
meas = dict()

for interface, config in CONFIGS.items():

    sizes_bytes = []
    durs_rd = []
    durs_wr = []

    for size in sizes_burst:
        size_bytes = size * BEATS_PER_BURST * BYTES_PER_BEAT
        sizes_bytes.append(size_bytes)

        for _ in range(NR_MEAS_PER_SIZE):
            stats = run_atg(interface, size, config)

            print(f"{size_bytes:8}: {stats}")
            assert size_bytes == stats.count_beats * BYTES_PER_BEAT

            durs_rd.append(stats.rd_cyc)
            durs_wr.append(stats.wr_cyc)

    meas[interface] = dict()
    meas[interface]["size"] = sizes_bytes
    meas[interface]["rd"] = durs_rd
    meas[interface]["wr"] = durs_wr
# Out:
#       64: Stats(rd_cyc=64, wr_cyc=37, count_beats=4)
#       64: Stats(rd_cyc=64, wr_cyc=36, count_beats=4)
#       64: Stats(rd_cyc=64, wr_cyc=36, count_beats=4)
#       64: Stats(rd_cyc=67, wr_cyc=36, count_beats=4)
#       64: Stats(rd_cyc=64, wr_cyc=37, count_beats=4)
#      128: Stats(rd_cyc=68, wr_cyc=40, count_beats=8)
#      128: Stats(rd_cyc=70, wr_cyc=39, count_beats=8)
#      128: Stats(rd_cyc=68, wr_cyc=39, count_beats=8)
#      128: Stats(rd_cyc=68, wr_cyc=40, count_beats=8)
#      128: Stats(rd_cyc=68, wr_cyc=40, count_beats=8)
#      256: Stats(rd_cyc=76, wr_cyc=47, count_beats=16)
#      256: Stats(rd_cyc=76, wr_cyc=48, count_beats=16)
#      256: Stats(rd_cyc=122, wr_cyc=47, count_beats=16)
#      256: Stats(rd_cyc=76, wr_cyc=47, count_beats=16)
#      256: Stats(rd_cyc=76, wr_cyc=47, count_beats=16)
#      512: Stats(rd_cyc=161, wr_cyc=79, count_beats=32)
#      512: Stats(rd_cyc=172, wr_cyc=79, count_beats=32)
#      512: Stats(rd_cyc=135, wr_cyc=79, count_beats=32)
#      512: Stats(rd_cyc=204, wr_cyc=77, count_beats=32)
#      512: Stats(rd_cyc=213, wr_cyc=79, count_beats=32)
#     1024: Stats(rd_cyc=322, wr_cyc=139, count_beats=64)
#     1024: Stats(rd_cyc=430, wr_cyc=140, count_beats=64)
#     1024: Stats(rd_cyc=339, wr_cyc=141, count_beats=64)
#     1024: Stats(rd_cyc=310, wr_cyc=143, count_beats=64)
#     1024: Stats(rd_cyc=386, wr_cyc=139, count_beats=64)
#     2048: Stats(rd_cyc=643, wr_cyc=264, count_beats=128)
#     2048: Stats(rd_cyc=655, wr_cyc=266, count_beats=128)
#     2048: Stats(rd_cyc=623, wr_cyc=265, count_beats=128)
#     2048: Stats(rd_cyc=665, wr_cyc=265, count_beats=128)
#     2048: Stats(rd_cyc=698, wr_cyc=267, count_beats=128)
#     4096: Stats(rd_cyc=1376, wr_cyc=514, count_beats=256)
#     4096: Stats(rd_cyc=1355, wr_cyc=516, count_beats=256)
#     4096: Stats(rd_cyc=1283, wr_cyc=516, count_beats=256)
#     4096: Stats(rd_cyc=1290, wr_cyc=514, count_beats=256)
#     4096: Stats(rd_cyc=1375, wr_cyc=515, count_beats=256)
#     8192: Stats(rd_cyc=2697, wr_cyc=1016, count_beats=512)
#     8192: Stats(rd_cyc=2590, wr_cyc=1015, count_beats=512)
#     8192: Stats(rd_cyc=2712, wr_cyc=1015, count_beats=512)
#     8192: Stats(rd_cyc=2628, wr_cyc=1016, count_beats=512)
#     8192: Stats(rd_cyc=2641, wr_cyc=1015, count_beats=512)
#    16384: Stats(rd_cyc=5331, wr_cyc=2017, count_beats=1024)
#    16384: Stats(rd_cyc=5285, wr_cyc=2014, count_beats=1024)
#    16384: Stats(rd_cyc=5142, wr_cyc=2017, count_beats=1024)
#    16384: Stats(rd_cyc=5325, wr_cyc=2014, count_beats=1024)
#    16384: Stats(rd_cyc=5341, wr_cyc=2014, count_beats=1024)
#    32768: Stats(rd_cyc=10277, wr_cyc=4017, count_beats=2048)
#    32768: Stats(rd_cyc=10297, wr_cyc=4014, count_beats=2048)
#    32768: Stats(rd_cyc=10274, wr_cyc=4014, count_beats=2048)
#    32768: Stats(rd_cyc=10318, wr_cyc=4017, count_beats=2048)
#    32768: Stats(rd_cyc=10367, wr_cyc=4017, count_beats=2048)
#    65536: Stats(rd_cyc=20456, wr_cyc=8016, count_beats=4096)
#    65536: Stats(rd_cyc=20546, wr_cyc=8015, count_beats=4096)
#    65536: Stats(rd_cyc=20586, wr_cyc=8170, count_beats=4096)
#    65536: Stats(rd_cyc=20578, wr_cyc=8016, count_beats=4096)
#    65536: Stats(rd_cyc=20512, wr_cyc=8175, count_beats=4096)
#   131072: Stats(rd_cyc=41074, wr_cyc=16405, count_beats=8192)
#   131072: Stats(rd_cyc=41156, wr_cyc=16146, count_beats=8192)
#   131072: Stats(rd_cyc=40959, wr_cyc=16315, count_beats=8192)
#   131072: Stats(rd_cyc=41291, wr_cyc=16165, count_beats=8192)
#   131072: Stats(rd_cyc=41120, wr_cyc=16333, count_beats=8192)
#   262144: Stats(rd_cyc=81977, wr_cyc=32324, count_beats=16384)
#   262144: Stats(rd_cyc=86391, wr_cyc=32349, count_beats=16384)
#   262144: Stats(rd_cyc=81972, wr_cyc=32320, count_beats=16384)
#   262144: Stats(rd_cyc=81947, wr_cyc=32014, count_beats=16384)
#   262144: Stats(rd_cyc=82004, wr_cyc=32015, count_beats=16384)
#   524288: Stats(rd_cyc=164049, wr_cyc=64014, count_beats=32768)
#   524288: Stats(rd_cyc=163971, wr_cyc=64017, count_beats=32768)
#   524288: Stats(rd_cyc=163979, wr_cyc=64603, count_beats=32768)
#   524288: Stats(rd_cyc=164327, wr_cyc=64208, count_beats=32768)
#   524288: Stats(rd_cyc=164103, wr_cyc=64017, count_beats=32768)
#  1048576: Stats(rd_cyc=328089, wr_cyc=128258, count_beats=65536)
#  1048576: Stats(rd_cyc=327903, wr_cyc=128017, count_beats=65536)
#  1048576: Stats(rd_cyc=328038, wr_cyc=128360, count_beats=65536)
#  1048576: Stats(rd_cyc=337367, wr_cyc=128536, count_beats=65536)
#  1048576: Stats(rd_cyc=328016, wr_cyc=128015, count_beats=65536)
#  2097152: Stats(rd_cyc=656338, wr_cyc=257286, count_beats=131072)
#  2097152: Stats(rd_cyc=656164, wr_cyc=256092, count_beats=131072)
#  2097152: Stats(rd_cyc=655970, wr_cyc=256015, count_beats=131072)
#  2097152: Stats(rd_cyc=655821, wr_cyc=256325, count_beats=131072)
#  2097152: Stats(rd_cyc=655892, wr_cyc=256176, count_beats=131072)
#  4194304: Stats(rd_cyc=1311899, wr_cyc=512015, count_beats=262144)
#  4194304: Stats(rd_cyc=1312291, wr_cyc=512016, count_beats=262144)
#  4194304: Stats(rd_cyc=1312808, wr_cyc=512015, count_beats=262144)
#  4194304: Stats(rd_cyc=1312017, wr_cyc=512016, count_beats=262144)
#  4194304: Stats(rd_cyc=1311809, wr_cyc=512251, count_beats=262144)
#  8388608: Stats(rd_cyc=2692853, wr_cyc=1024018, count_beats=524288)
#  8388608: Stats(rd_cyc=2624761, wr_cyc=1024500, count_beats=524288)
#  8388608: Stats(rd_cyc=2623281, wr_cyc=1024289, count_beats=524288)
#  8388608: Stats(rd_cyc=2624084, wr_cyc=1024249, count_beats=524288)
#  8388608: Stats(rd_cyc=2623951, wr_cyc=1024142, count_beats=524288)
# 16777216: Stats(rd_cyc=5247763, wr_cyc=2048442, count_beats=1048576)
# 16777216: Stats(rd_cyc=5248062, wr_cyc=2048015, count_beats=1048576)
# 16777216: Stats(rd_cyc=5248125, wr_cyc=2050856, count_beats=1048576)
# 16777216: Stats(rd_cyc=5247453, wr_cyc=2048019, count_beats=1048576)
# 16777216: Stats(rd_cyc=5247889, wr_cyc=2048341, count_beats=1048576)
# 33554432: Stats(rd_cyc=10495312, wr_cyc=4096017, count_beats=2097152)
# 33554432: Stats(rd_cyc=10494680, wr_cyc=4096017, count_beats=2097152)
# 33554432: Stats(rd_cyc=10494354, wr_cyc=4096926, count_beats=2097152)
# 33554432: Stats(rd_cyc=10494901, wr_cyc=4096015, count_beats=2097152)
# 33554432: Stats(rd_cyc=10495124, wr_cyc=4096014, count_beats=2097152)
#       64: Stats(rd_cyc=41, wr_cyc=66, count_beats=4)
#       64: Stats(rd_cyc=41, wr_cyc=66, count_beats=4)
#       64: Stats(rd_cyc=41, wr_cyc=66, count_beats=4)
#       64: Stats(rd_cyc=41, wr_cyc=65, count_beats=4)
#       64: Stats(rd_cyc=41, wr_cyc=65, count_beats=4)
#      128: Stats(rd_cyc=46, wr_cyc=88, count_beats=8)
#      128: Stats(rd_cyc=46, wr_cyc=87, count_beats=8)
#      128: Stats(rd_cyc=48, wr_cyc=87, count_beats=8)
#      128: Stats(rd_cyc=45, wr_cyc=87, count_beats=8)
#      128: Stats(rd_cyc=45, wr_cyc=87, count_beats=8)
#      256: Stats(rd_cyc=55, wr_cyc=1068, count_beats=16)
#      256: Stats(rd_cyc=60, wr_cyc=1072, count_beats=16)
#      256: Stats(rd_cyc=57, wr_cyc=128, count_beats=16)
#      256: Stats(rd_cyc=60, wr_cyc=964, count_beats=16)
#      256: Stats(rd_cyc=55, wr_cyc=127, count_beats=16)
#      512: Stats(rd_cyc=97, wr_cyc=224, count_beats=32)
#      512: Stats(rd_cyc=100, wr_cyc=216, count_beats=32)
#      512: Stats(rd_cyc=97, wr_cyc=240, count_beats=32)
#      512: Stats(rd_cyc=101, wr_cyc=224, count_beats=32)
#      512: Stats(rd_cyc=96, wr_cyc=220, count_beats=32)
#     1024: Stats(rd_cyc=180, wr_cyc=412, count_beats=64)
#     1024: Stats(rd_cyc=181, wr_cyc=409, count_beats=64)
#     1024: Stats(rd_cyc=181, wr_cyc=409, count_beats=64)
#     1024: Stats(rd_cyc=184, wr_cyc=448, count_beats=64)
#     1024: Stats(rd_cyc=182, wr_cyc=409, count_beats=64)
#     2048: Stats(rd_cyc=549, wr_cyc=819, count_beats=128)
#     2048: Stats(rd_cyc=594, wr_cyc=769, count_beats=128)
#     2048: Stats(rd_cyc=579, wr_cyc=780, count_beats=128)
#     2048: Stats(rd_cyc=492, wr_cyc=781, count_beats=128)
#     2048: Stats(rd_cyc=548, wr_cyc=782, count_beats=128)
#     4096: Stats(rd_cyc=2467, wr_cyc=1505, count_beats=256)
#     4096: Stats(rd_cyc=2429, wr_cyc=1530, count_beats=256)
#     4096: Stats(rd_cyc=2577, wr_cyc=1551, count_beats=256)
#     4096: Stats(rd_cyc=2364, wr_cyc=1507, count_beats=256)
#     4096: Stats(rd_cyc=2417, wr_cyc=1523, count_beats=256)
#     8192: Stats(rd_cyc=4722, wr_cyc=3046, count_beats=512)
#     8192: Stats(rd_cyc=4934, wr_cyc=3031, count_beats=512)
#     8192: Stats(rd_cyc=4590, wr_cyc=3004, count_beats=512)
#     8192: Stats(rd_cyc=4890, wr_cyc=3049, count_beats=512)
#     8192: Stats(rd_cyc=4983, wr_cyc=2993, count_beats=512)
#    16384: Stats(rd_cyc=9474, wr_cyc=5998, count_beats=1024)
#    16384: Stats(rd_cyc=10465, wr_cyc=5971, count_beats=1024)
#    16384: Stats(rd_cyc=10101, wr_cyc=6031, count_beats=1024)
#    16384: Stats(rd_cyc=9749, wr_cyc=6041, count_beats=1024)
#    16384: Stats(rd_cyc=10294, wr_cyc=5972, count_beats=1024)
#    32768: Stats(rd_cyc=20405, wr_cyc=11840, count_beats=2048)
#    32768: Stats(rd_cyc=21080, wr_cyc=11991, count_beats=2048)
#    32768: Stats(rd_cyc=21062, wr_cyc=12055, count_beats=2048)
#    32768: Stats(rd_cyc=21146, wr_cyc=12121, count_beats=2048)
#    32768: Stats(rd_cyc=20285, wr_cyc=12020, count_beats=2048)
#    65536: Stats(rd_cyc=42161, wr_cyc=24074, count_beats=4096)
#    65536: Stats(rd_cyc=41580, wr_cyc=23897, count_beats=4096)
#    65536: Stats(rd_cyc=41706, wr_cyc=23899, count_beats=4096)
#    65536: Stats(rd_cyc=41469, wr_cyc=24298, count_beats=4096)
#    65536: Stats(rd_cyc=41574, wr_cyc=24253, count_beats=4096)
#   131072: Stats(rd_cyc=83642, wr_cyc=48562, count_beats=8192)
#   131072: Stats(rd_cyc=90562, wr_cyc=48650, count_beats=8192)
#   131072: Stats(rd_cyc=83569, wr_cyc=48319, count_beats=8192)
#   131072: Stats(rd_cyc=83585, wr_cyc=48415, count_beats=8192)
#   131072: Stats(rd_cyc=83490, wr_cyc=48808, count_beats=8192)
#   262144: Stats(rd_cyc=166699, wr_cyc=96809, count_beats=16384)
#   262144: Stats(rd_cyc=167480, wr_cyc=97667, count_beats=16384)
#   262144: Stats(rd_cyc=166920, wr_cyc=97018, count_beats=16384)
#   262144: Stats(rd_cyc=164118, wr_cyc=96957, count_beats=16384)
#   262144: Stats(rd_cyc=167567, wr_cyc=97126, count_beats=16384)
#   524288: Stats(rd_cyc=342438, wr_cyc=191669, count_beats=32768)
#   524288: Stats(rd_cyc=334368, wr_cyc=191245, count_beats=32768)
#   524288: Stats(rd_cyc=333272, wr_cyc=190487, count_beats=32768)
#   524288: Stats(rd_cyc=339836, wr_cyc=191243, count_beats=32768)
#   524288: Stats(rd_cyc=332042, wr_cyc=191060, count_beats=32768)
#  1048576: Stats(rd_cyc=532874, wr_cyc=239120, count_beats=65536)
#  1048576: Stats(rd_cyc=750693, wr_cyc=322394, count_beats=65536)
#  1048576: Stats(rd_cyc=765497, wr_cyc=330282, count_beats=65536)
#  1048576: Stats(rd_cyc=753063, wr_cyc=314607, count_beats=65536)
#  1048576: Stats(rd_cyc=760413, wr_cyc=338254, count_beats=65536)
#  2097152: Stats(rd_cyc=1142621, wr_cyc=361931, count_beats=131072)
#  2097152: Stats(rd_cyc=1137589, wr_cyc=358009, count_beats=131072)
#  2097152: Stats(rd_cyc=1140289, wr_cyc=359855, count_beats=131072)
#  2097152: Stats(rd_cyc=1141696, wr_cyc=362788, count_beats=131072)
#  2097152: Stats(rd_cyc=907181, wr_cyc=359175, count_beats=131072)
#  4194304: Stats(rd_cyc=1900743, wr_cyc=684313, count_beats=262144)
#  4194304: Stats(rd_cyc=1908799, wr_cyc=683817, count_beats=262144)
#  4194304: Stats(rd_cyc=1909696, wr_cyc=683896, count_beats=262144)
#  4194304: Stats(rd_cyc=1901505, wr_cyc=684348, count_beats=262144)
#  4194304: Stats(rd_cyc=1879343, wr_cyc=683856, count_beats=262144)
#  8388608: Stats(rd_cyc=3433534, wr_cyc=1368461, count_beats=524288)
#  8388608: Stats(rd_cyc=3422703, wr_cyc=1360482, count_beats=524288)
#  8388608: Stats(rd_cyc=3436772, wr_cyc=1368064, count_beats=524288)
#  8388608: Stats(rd_cyc=3441536, wr_cyc=1368446, count_beats=524288)
#  8388608: Stats(rd_cyc=3449316, wr_cyc=1368877, count_beats=524288)
# 16777216: Stats(rd_cyc=6466893, wr_cyc=2737672, count_beats=1048576)
# 16777216: Stats(rd_cyc=6448252, wr_cyc=2732443, count_beats=1048576)
# 16777216: Stats(rd_cyc=6484559, wr_cyc=2737512, count_beats=1048576)
# 16777216: Stats(rd_cyc=6480714, wr_cyc=2725350, count_beats=1048576)
# 16777216: Stats(rd_cyc=6495209, wr_cyc=2735691, count_beats=1048576)
# 33554432: Stats(rd_cyc=12580275, wr_cyc=5476262, count_beats=2097152)
# 33554432: Stats(rd_cyc=12535508, wr_cyc=5471795, count_beats=2097152)
# 33554432: Stats(rd_cyc=12534969, wr_cyc=5475893, count_beats=2097152)
# 33554432: Stats(rd_cyc=12547621, wr_cyc=5475975, count_beats=2097152)
# 33554432: Stats(rd_cyc=12517258, wr_cyc=5476438, count_beats=2097152)
#       64: Stats(rd_cyc=24, wr_cyc=22, count_beats=4)
#       64: Stats(rd_cyc=24, wr_cyc=18, count_beats=4)
#       64: Stats(rd_cyc=13, wr_cyc=15, count_beats=4)
#       64: Stats(rd_cyc=13, wr_cyc=22, count_beats=4)
#       64: Stats(rd_cyc=25, wr_cyc=25, count_beats=4)
#      128: Stats(rd_cyc=17, wr_cyc=38, count_beats=8)
#      128: Stats(rd_cyc=21, wr_cyc=38, count_beats=8)
#      128: Stats(rd_cyc=25, wr_cyc=25, count_beats=8)
#      128: Stats(rd_cyc=24, wr_cyc=29, count_beats=8)
#      128: Stats(rd_cyc=17, wr_cyc=37, count_beats=8)
#      256: Stats(rd_cyc=37, wr_cyc=52, count_beats=16)
#      256: Stats(rd_cyc=37, wr_cyc=56, count_beats=16)
#      256: Stats(rd_cyc=26, wr_cyc=55, count_beats=16)
#      256: Stats(rd_cyc=32, wr_cyc=62, count_beats=16)
#      256: Stats(rd_cyc=28, wr_cyc=58, count_beats=16)
#      512: Stats(rd_cyc=52, wr_cyc=91, count_beats=32)
#      512: Stats(rd_cyc=48, wr_cyc=98, count_beats=32)
#      512: Stats(rd_cyc=42, wr_cyc=88, count_beats=32)
#      512: Stats(rd_cyc=45, wr_cyc=84, count_beats=32)
#      512: Stats(rd_cyc=49, wr_cyc=91, count_beats=32)
#     1024: Stats(rd_cyc=73, wr_cyc=150, count_beats=64)
#     1024: Stats(rd_cyc=73, wr_cyc=143, count_beats=64)
#     1024: Stats(rd_cyc=75, wr_cyc=138, count_beats=64)
#     1024: Stats(rd_cyc=73, wr_cyc=144, count_beats=64)
#     1024: Stats(rd_cyc=80, wr_cyc=146, count_beats=64)
#     2048: Stats(rd_cyc=141, wr_cyc=238, count_beats=128)
#     2048: Stats(rd_cyc=141, wr_cyc=258, count_beats=128)
#     2048: Stats(rd_cyc=140, wr_cyc=250, count_beats=128)
#     2048: Stats(rd_cyc=139, wr_cyc=256, count_beats=128)
#     2048: Stats(rd_cyc=143, wr_cyc=257, count_beats=128)
#     4096: Stats(rd_cyc=276, wr_cyc=466, count_beats=256)
#     4096: Stats(rd_cyc=276, wr_cyc=468, count_beats=256)
#     4096: Stats(rd_cyc=276, wr_cyc=482, count_beats=256)
#     4096: Stats(rd_cyc=276, wr_cyc=493, count_beats=256)
#     4096: Stats(rd_cyc=272, wr_cyc=465, count_beats=256)
#     8192: Stats(rd_cyc=522, wr_cyc=909, count_beats=512)
#     8192: Stats(rd_cyc=521, wr_cyc=929, count_beats=512)
#     8192: Stats(rd_cyc=532, wr_cyc=886, count_beats=512)
#     8192: Stats(rd_cyc=533, wr_cyc=932, count_beats=512)
#     8192: Stats(rd_cyc=521, wr_cyc=920, count_beats=512)
#    16384: Stats(rd_cyc=1033, wr_cyc=1691, count_beats=1024)
#    16384: Stats(rd_cyc=1040, wr_cyc=1895, count_beats=1024)
#    16384: Stats(rd_cyc=1043, wr_cyc=1895, count_beats=1024)
#    16384: Stats(rd_cyc=1033, wr_cyc=1809, count_beats=1024)
#    16384: Stats(rd_cyc=1045, wr_cyc=1733, count_beats=1024)
#    32768: Stats(rd_cyc=2064, wr_cyc=3116, count_beats=2048)
#    32768: Stats(rd_cyc=2069, wr_cyc=3436, count_beats=2048)
#    32768: Stats(rd_cyc=2064, wr_cyc=3365, count_beats=2048)
#    32768: Stats(rd_cyc=2064, wr_cyc=3410, count_beats=2048)
#    32768: Stats(rd_cyc=2065, wr_cyc=3171, count_beats=2048)
#    65536: Stats(rd_cyc=4109, wr_cyc=5994, count_beats=4096)
#    65536: Stats(rd_cyc=4112, wr_cyc=6173, count_beats=4096)
#    65536: Stats(rd_cyc=4108, wr_cyc=6052, count_beats=4096)
#    65536: Stats(rd_cyc=4105, wr_cyc=6137, count_beats=4096)
#    65536: Stats(rd_cyc=4105, wr_cyc=5986, count_beats=4096)
#   131072: Stats(rd_cyc=8205, wr_cyc=11914, count_beats=8192)
#   131072: Stats(rd_cyc=8202, wr_cyc=11873, count_beats=8192)
#   131072: Stats(rd_cyc=9166, wr_cyc=11768, count_beats=8192)
#   131072: Stats(rd_cyc=8209, wr_cyc=11697, count_beats=8192)
#   131072: Stats(rd_cyc=8201, wr_cyc=11531, count_beats=8192)
#   262144: Stats(rd_cyc=16395, wr_cyc=23486, count_beats=16384)
#   262144: Stats(rd_cyc=16405, wr_cyc=22653, count_beats=16384)
#   262144: Stats(rd_cyc=16407, wr_cyc=23060, count_beats=16384)
#   262144: Stats(rd_cyc=16403, wr_cyc=22835, count_beats=16384)
#   262144: Stats(rd_cyc=16401, wr_cyc=22842, count_beats=16384)
#   524288: Stats(rd_cyc=32786, wr_cyc=45171, count_beats=32768)
#   524288: Stats(rd_cyc=32788, wr_cyc=45488, count_beats=32768)
#   524288: Stats(rd_cyc=32778, wr_cyc=45753, count_beats=32768)
#   524288: Stats(rd_cyc=32781, wr_cyc=45231, count_beats=32768)
#   524288: Stats(rd_cyc=32778, wr_cyc=45579, count_beats=32768)
#  1048576: Stats(rd_cyc=265340, wr_cyc=159147, count_beats=65536)
#  1048576: Stats(rd_cyc=213995, wr_cyc=128998, count_beats=65536)
#  1048576: Stats(rd_cyc=226597, wr_cyc=135439, count_beats=65536)
#  1048576: Stats(rd_cyc=223970, wr_cyc=135121, count_beats=65536)
#  1048576: Stats(rd_cyc=166542, wr_cyc=137849, count_beats=65536)
#  2097152: Stats(rd_cyc=2616821, wr_cyc=676295, count_beats=131072)
#  2097152: Stats(rd_cyc=2500721, wr_cyc=669264, count_beats=131072)
#  2097152: Stats(rd_cyc=2478812, wr_cyc=664045, count_beats=131072)
#  2097152: Stats(rd_cyc=2496650, wr_cyc=665741, count_beats=131072)
#  2097152: Stats(rd_cyc=2601841, wr_cyc=695971, count_beats=131072)
#  4194304: Stats(rd_cyc=5235473, wr_cyc=1398501, count_beats=262144)
#  4194304: Stats(rd_cyc=5234144, wr_cyc=1399149, count_beats=262144)
#  4194304: Stats(rd_cyc=5239853, wr_cyc=1381648, count_beats=262144)
#  4194304: Stats(rd_cyc=5230952, wr_cyc=1401577, count_beats=262144)
#  4194304: Stats(rd_cyc=5230316, wr_cyc=1401733, count_beats=262144)
#  8388608: Stats(rd_cyc=10476117, wr_cyc=2780299, count_beats=524288)
#  8388608: Stats(rd_cyc=10469742, wr_cyc=2811417, count_beats=524288)
#  8388608: Stats(rd_cyc=10500224, wr_cyc=2810681, count_beats=524288)
#  8388608: Stats(rd_cyc=10475687, wr_cyc=2810360, count_beats=524288)
#  8388608: Stats(rd_cyc=10493873, wr_cyc=2810973, count_beats=524288)
# 16777216: Stats(rd_cyc=20984591, wr_cyc=5636958, count_beats=1048576)
# 16777216: Stats(rd_cyc=20973534, wr_cyc=5636524, count_beats=1048576)
# 16777216: Stats(rd_cyc=20965250, wr_cyc=5637165, count_beats=1048576)
# 16777216: Stats(rd_cyc=20971391, wr_cyc=5636823, count_beats=1048576)
# 16777216: Stats(rd_cyc=20965520, wr_cyc=5636478, count_beats=1048576)
# 33554432: Stats(rd_cyc=41946146, wr_cyc=11288858, count_beats=2097152)
# 33554432: Stats(rd_cyc=41957455, wr_cyc=11288566, count_beats=2097152)
# 33554432: Stats(rd_cyc=41961290, wr_cyc=11289521, count_beats=2097152)
# 33554432: Stats(rd_cyc=41950849, wr_cyc=11288184, count_beats=2097152)
# 33554432: Stats(rd_cyc=41970287, wr_cyc=11288313, count_beats=2097152)

# %% [markdown]
# ## Plotting

# %%
@dataclass
class MeasData:
    sizes: np.array
    rd_beat_per_cyc: np.array
    wr_beat_per_cyc: np.array
    sizes_avg: np.array
    rd_beat_per_cyc_avg: np.array
    wr_beat_per_cyc_avg: np.array

# %%
def process_meas(data):
    SAMP_PER_SIZE = len(data["rd"]) // len(data["size"])

    sizes_avg = np.array(data["size"])
    sizes = np.repeat(sizes_avg.reshape((-1, 1)), SAMP_PER_SIZE, axis=1).reshape(-1)

    rd = np.array(data["rd"])
    wr = np.array(data["wr"])

    avg = lambda xs: np.mean(xs.reshape((-1, SAMP_PER_SIZE)), axis=1)
    rd_avg = avg(rd)
    wr_avg = avg(wr)

    rd_beat_per_cyc = (sizes / BYTES_PER_BEAT) / rd
    wr_beat_per_cyc = (sizes / BYTES_PER_BEAT) / wr
    rd_beat_per_cyc_avg = (sizes_avg / BYTES_PER_BEAT) / rd_avg
    wr_beat_per_cyc_avg = (sizes_avg / BYTES_PER_BEAT) / wr_avg

    return MeasData(
        sizes,
        rd_beat_per_cyc,
        wr_beat_per_cyc,
        sizes_avg,
        rd_beat_per_cyc_avg,
        wr_beat_per_cyc_avg,
    )

# %%
data_apc = process_meas(meas["acp"])
data_hpc = process_meas(meas["hpc"])
data_hp = process_meas(meas["hp"])

# %%
fig = plt.figure(figsize=(12, 10))

ax2, ax1 = fig.subplots(2, 1, sharex=True)

ax1.semilogx(
    data_apc.sizes,
    data_apc.rd_beat_per_cyc,
    "x",
    color="C2",
    label="ACP",
)
ax1.semilogx(
    data_apc.sizes_avg,
    data_apc.rd_beat_per_cyc_avg,
    color="C2",
    label="ACP (avg)",
)
ax1.semilogx(
    data_hpc.sizes,
    data_hpc.rd_beat_per_cyc,
    "x",
    color="C1",
    label="HPC",
)
ax1.semilogx(
    data_hpc.sizes_avg,
    data_hpc.rd_beat_per_cyc_avg,
    color="C1",
    label="HPC (avg)",
)
ax1.semilogx(
    data_hp.sizes,
    data_hp.rd_beat_per_cyc,
    "x",
    color="C0",
    label="HP",
)
ax1.semilogx(
    data_hp.sizes_avg,
    data_hp.rd_beat_per_cyc_avg,
    color="C0",
    label="HP (avg)",
)

ax1.set_ylim((0, 1))
ax1.grid(True)
ax1.legend()
ax1.set_title("read throughput")
ax1.set_ylabel("beats / clk cycle")
ax1.set_xscale("log", base=2)

ax2.semilogx(
    data_apc.sizes,
    data_apc.wr_beat_per_cyc,
    "x",
    color="C2",
    label="ACP",
)
ax2.semilogx(
    data_apc.sizes_avg,
    data_apc.wr_beat_per_cyc_avg,
    color="C2",
    label="ACP (avg)",
)
ax2.semilogx(
    data_hpc.sizes,
    data_hpc.wr_beat_per_cyc,
    "x",
    color="C1",
    label="HPC",
)
ax2.semilogx(
    data_hpc.sizes_avg,
    data_hpc.wr_beat_per_cyc_avg,
    color="C1",
    label="HPC (avg)",
)
ax2.semilogx(
    data_hp.sizes,
    data_hp.wr_beat_per_cyc,
    "x",
    color="C0",
    label="HP",
)
ax2.semilogx(
    data_hp.sizes_avg,
    data_hp.wr_beat_per_cyc_avg,
    color="C0",
    label="HP (avg)",
)

ax2.set_ylim((0, 1))
ax2.grid(True)
ax2.legend()
ax2.set_title("write throughput")
ax2.set_ylabel("beats / clk cycle")
ax2.set_xscale("log", base=2)

ax1.set_xlabel("transfer size [bytes]")

fig.suptitle("AXI Traffic Gen, clk freq = 250 MHz")
# Out:
# Text(0.5, 0.98, 'AXI Traffic Gen, clk freq = 250 MHz')

# %% [markdown]
# ## Conclusion
#
# * all AXI Traffic Generators use the same configuration: 4 burst in flight, each burst has 64 bytes (one cache line); this satisfies the requirements on the ACP port
# * those values are too low for the HP and HPC ports (with high latencies of the DDR4 memory) to achieve a decent throughput
# * because we first write and then read is the read performance on ACP port fanstastic ...
# * ... until the transfer size reaches the L2 cache size (1 MB - 2^20 bytes), L1 cache size (32 kB - 2^15 bytes) is also visible on the ACP write throughput
